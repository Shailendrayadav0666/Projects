# %%
import string
from collections import Counter

import matplotlib.pyplot as plt

# %%
def get_tweets():
    import GetOldTweets3 as got 
    tweetCriteria=got.manager.TweetCriteria().setQuerySearch('#covid19') \
        .setSince("2017-06-03") \
        .setSince("2017-07-03") \
        .setMaxTweets(100)
    tweets=got.manager.TweetManager.getTweets(tweetCriteria)
    text_tweets=[[tweet.text] for tweet in tweets]
    return text_tweets

# %%
text=""
text_tweets=get_tweets()

# %%
length=len(text_tweets)
length
# Out:
# 100

# %%
text_tweets[5]
# Out:
# ['Spain Mounting #Coronavirus https://nzzl.us/EJgoxSX #covid19 Crisis Is Met by Government http://photocontact.blogspot.com.es/2015/03/silvio-berlusconi-telecinco.html Silence Bloomberg']

# %%
text_tweets
# Out:
# [['Wie würde die Coronavirus-Pandemie wohl auf Kronos verlaufen? Die Klingonen würden sicher alle Maske tragen, weil es unehrenhaft ist, an einer Krankheit zu sterben. "Heghlu\'meH QaQ jajvam" gilt ja wohl kaum für #COVID19!'],
#  ["Il va falloir surtout suivre l'évolution de l'atteinte pulmonaire. S'achemine-t-on vers des séquelles fixées à l'origine d'insuffisance respiratoire chronique? #afrique #gabon #COVID19 Covid-19 – When covid-19 becomes a chronic illness "],
#  ['Right now it isn’t #COVID19 '],
#  ['Singapore will allow general travel to Brunei and New Zealand after months of #COVID19 restrictions '],
#  ['Lo último de Binnari tiene un rollo muy boho https://bit.ly/2JWSQdb #lifestyle #yomequedoencasa #covid19'],
#  ['Spain Mounting #Coronavirus https://nzzl.us/EJgoxSX #covid19 Crisis Is Met by Government http://photocontact.blogspot.com.es/2015/03/silvio-berlusconi-telecinco.html Silence Bloomberg'],
#  ['@lopezobrador_ Buenas noches señor presidente, le escribo por medio de Twitter para poder ver si le podía hacer una entrevista y hablar sobre temas del #COVID19 , tratar asuntos que pasan en la República mexicana y más. También le mando la cordial invitación a @JacoboWong.'],
#  ['#COVID19 #COVID #COVIDIOTS'],
#  ['Heute ist Tag 235 von 366. Oder anders gesagt: 64,21% des Jahres sind rum. Tag 208 seit Ausbruch von #Covid19 in Deutschland. Gestorben: 9.328 | +14 Genesen: 205.751 | +1.908 Bestätigte Fälle: 233.021 | +3.333 Anzahl der Heilmittel: 0 Tragt eure verdammten #Masken ihr Penner!'],
#  ['Holiday makers in Croatia saying they would of preferred more notice.... pretty sure this pandemic has been around for a million months now #COVID19'],
#  ['About to order a new shirt and I get to the name and number box... #NUFC #COVID19 '],
#  ['Mobility App advertised on #skyNAD during one program placement in the week ending August 9. Please discuss with Damian Cook (MD) their advertising in support of racism, hatred, falsehoods on #COVID19 and misogyny at https://buff.ly/33S8Mc8 cc @slpng_giants_oz'],
#  [' #CoronaVirusUpdates: #COVID19 India Tracker (As on 22 August, 2020, 08:00 AM) Confirmed cases: 29,75,701 Recovered: 2,222,577 (74.7%) Active cases: 6,97,330 (23.4%) Deaths: 55,794 (1.9%) #IndiaFightsCorona #IndiaWillWin #StaySafe'],
#  ['#Dünya genelinde tespit edilen #Covid19 vaka sayısı 23 milyonu aştı | Dogrusu '],
#  ["Ces qualités sont mises à l'épreuve pendant la crise #Covid19: les internes de santé publique de l'hexagone et des outre-mer n'ont pas hésité un seul instant et se sont immédiatement impliqués là où ils ont pu apporter leur aide (cf bulletin n° 41 du @clispfr qui sort bientôt) "],
#  ['Great thread to read on QR code adoption/use cases. Personally, I still feel there are some MITM security issues for certain uses which people shouldn’t take for granted. #fintech #healthcare #contactless #covid19 #qrcodes'],
#  ['Onam 2020: Kerala CM Pinarayi Vijayan Calls for Indoor Celebrations Amid COVID-19 Pandemic https://www.latestly.com/india/news/onam-2020-kerala-cm-pinarayi-vijayan-calls-for-indoor-celebrations-amid-covid-19-pandemic-1979591.html #Onam2020 #PinarayiVijayan #Kerala #COVID19'],
#  ['Love the government coming out with these new labels for places being looked at. Apparently Birmingham is now an ‘Area of enhanced support’ To the general public it means, lots of people are being dicks, keep an eye on them! #COVID19'],
#  ['ଭଦ୍ରକରୁ ଆଜି ଚିହ୍ନଟ ହୋଇଥିବା ୭୭ଜଣ କରୋନା ଆକ୍ରାନ୍ତଙ୍କ ମଧ୍ୟରୁ ୭୬ ଜଣ ସ୍ଥାନୀୟ ସଂକ୍ରମିତ । ଟୁଇଟ୍ କରି ସୂଚନା ଦେଲା @DM_Bhadrak। #KanakNews #COVID19 #Odisha'],
#  ["They're the strictest restrictions in Queensland since May. But today many weren't abiding by or even aware of the new rules after the shock announcement at 8am. More:https://7news.link/2EdGPAQ @G_Chumbley #covid19 #7NEWS"],
#  ['do you expect new lockdowns this fall? #SARSCoV2 #COVID19'],
#  ['#IndiaFightsCorona: Preventing #COVID19 at Workplaces Make sure your workplace is clean &amp; hygienic. Regularly disinfect surfaces and objects. Promote regular hand-washing by employees. #StaySafe #indiawillwin Via MIB @PMOIndia @InfoDeptUP @BOC_MIB @MIB_India'],
#  ['ईएसआईसी अस्पतालों में कुल बेडों के 10 प्रतिशत पर आईसीयू/एचडीयू सेवाओं की स्थापना ईएसआई कॉरपोरेशन सदस्यों ने #COVID19 महामारी के दौरान ईएसआईसी द्वारा उठाये गए कदमों की सराहना की https://www.pib.gov.in/PressReleasePage.aspx?PRID=1647560#'],
#  ['El grito de las parejas separadas por el #COVID19. No están casados y el virus les pilló en distintos países. Piden que los Estados consideren su excepcional situación y les dejen volver a encontrarse. Con @pepebarahona EN @elconfidencial #LoveIsNotTourism https://www.elconfidencial.com/espana/2020-08-22/parejas-distintos-paises-piden-volver-a-encontrarse_2721899/?utm_campaign=BotoneraWebapp&amp;utm_source=whatsapp&amp;utm_medium=social'],
#  ['Test Négatif Par contre de plus en plus de positifs dans mon entourage, protégez vous pour protéger les autres. les #AlpesMaritimes sont en proie à une grosse #2emeVague . #Cannes et #Antibes en particulier. Restez prudents #Covid19 #Covid_19'],
#  ['L’Institut #Pasteur et #Microsoft ont les brevets du #COVID19 http://www.brujitafr.fr/2020/08/l-institut-pasteur-et-microsoft-ont-les-brevets-du-covid-19.html #ACTUALITES #SANTE #vaccin #NouvelOrdreMondial via'],
#  ['En el conjunto de España, sigue la tendencia de semanas anteriores. Muy preocupante. #COVID19 '],
#  ['"We are reporting, as the evidence reveals, that the number of COVID-positive results and the number of COVID-related deaths have been significantly exaggerated." There are two sides to the #COVID19 debate but we are only ever presented with one... '],
#  ["COVID19 made me more of a firm believer in what Voltaire said about the importance of work in our daily lives. I can't believe I am saying this, but I miss going everyday to work and enjoy being around some of my students. #COVID19"],
#  ['KUMPIRMADONG KASO NG COVID-19 SA PILIPINAS AY LAGPAS 187,000 NA Nakapagtala pa ang DOH ng 4,933 na bagong kaso ng #COVID19, kaya ang kabuuang bilang ng mga kumpirmadong kaso sa bansa ay 187,249 na. Mayroon din 436 bagong naitalang gumaling at 26 na namatay. '],
#  ['#FelizSabado #FelizFinde Es necesario seguir teniendo precauciones. Hay que ser responsables por nosotros y por los demás. Los casos aumentan de manera importante. Hay que cuidarse por responsabilidad, por solidaridad, por caridad y amor a los demás. #COVID19 #coronavirus'],
#  ['#COVID19 En resumen, es fundamental para el desarrollo de los niños y para la reactivación de la economía reabrir las escuelas. Hay riesgos, pero se pueden mitigar con una planificación cuidadosa, el apoyo del gobierno, y si todos usamos mascarillas para reducir la propagación.'],
#  ['#COVID19 Por último, estas tablas de riesgo aplican a estudiantes y profesores sin ninguna condición subyacente que los haga especialmente vulnerables. Todos los colegios necesitan además tener opciones virtuales para un aprendizaje seguro... y los profes para trabajar.'],
#  ['#COVID19 El recreo y el atletismo, aunque también son importantes, tienen sus propios desafíos. Los deportes de contacto suponen un alto riesgo, así como los vestuarios. Los patios de recreo al aire libre son de mucho menor riesgo, como lo son las pistas al aire libre. '],
#  ['#COVID19 Las actividades extraescolares son importantes, pero algunas representar un alto riesgo. Por ejemplo, los coros, con muchas personas juntas exhalando con fuerza durante mucho tiempo, especialmente peligrosa. Este año escolar, es más seguro evitar algunas. '],
#  ['So true....especially this year.... #2020 #COVID19 #pandemic'],
#  ['#COVID19 La hora de comer es otro momento del día potencialmente peligroso en los colegios. Es más seguro recoger una comida preenvasada que esperar en la cola de una cafetería, y es más seguro comer al aire libre que en el comedor. '],
#  ['Congratulations @DrTedros to join #incompetencetedros and for promoting the #COVID19 pandemic.'],
#  ['#COVID19 Los períodos entre clases son de alto riesgo, ya que los estudiantes llenan los pasillos y el distanciamiento social se hace casi imposible. '],
#  ['#COVID19 Lo más seguro es llevar a los niños en coche, si se puede ir andando andando o en bici mejor. El autobús escolar y el transporte público incrementan los riesgos. '],
#  ['#COVID19 Los otros requisitos son las medidas a adoptar en los coles: distanciamiento físico, uso de mascarillas, lavado de manos, trasladar las actividades al exterior o invertir en ventilación (los filtros portátiles HEPA ayudan, pero necesitan de esas otras medidas). '],
#  ['#COVID19 Si se cumplen esos niveles, todavía existen riesgos de que alguien se infecte, pero según los científicos mencionados y la @AmerAcadPeds, los beneficios psicosociales, educativos y de salud de la escuela presencial compensan el riesgo: http://bit.ly/apeds'],
#  ['#COVID19 No he encontrado datos demasiado actualizados sobre la tasa de positividad por CCAAs (% de PCR positivas / Total PCR efectuados). Esta tabla está elaborada por @elconfidencial (fechas 31 Jul-6 Agosto), seguro que la foto ha cambiado.'],
#  ['A Window Inside the Body and #COVID19 ; #medical imaging during the global #pandemic Refining and adapting - Chest #XRays , #Chest #CT ( #ComputedTomography), #Lung #ultrasound Nicole Jawerth @iaeaorg https://www.iaea.org/bulletin/infectious-diseases/a-window-inside-the-body-and-covid-19'],
#  ['கரோனா தொற்று குழந்தைகளைத் தாக்குமா? #coronavirus #COVID19 '],
#  ['#COVID19 Si nos fijamos en esta tabla de @ngbpadel2 podemos ver que hay varias comunidades que no cumplen con el criterio de &lt;75 casos x 100.000 hab. a día de hoy.'],
#  ['#COVID19 Requisitos para la apertura que proponen: las escuelas sólo deben abrir en lugares donde la transmisión comunitaria sea inferior a 75 casos x 100.000 hab en los últimos 7 días con una tasa de positividad en los test inferior al 5%.'],
#  ['#COVID19 Tenéis el hilo original en inglés aquí: '],
#  ['#COVID19 Este artículo de @ZekeEmanuel @SaskiaPopescu y @DrPhillipsMD es un buenísimo punto de partida, pero la matriz gráfica que adjunto es excepcional (K-12 es primaria y secundaria en USA) https://www.nytimes.com/2020/07/29/opinion/coronavirus-schools-reopen.html'],
#  ['#COVID19 Como sabéis, he ido analizando propuestas y protocolos a medida que se han ido publicando. No solo los de las distintas CCAA autónomas españolas, también los de otros países e instituciones extranjeras. Lo tenéis todo aquí: '],
#  ['#COVID19 ¿Vuelta al cole presencial? si...pero si se cumplen TODOS estos requisitos. Hilo '],
#  ['This is how our Media expose the news with imagination SC denied seeking plea against #JEE_NEET2020 postpone few days back But They exposed Exams in the #Covid19 period is not good for students They will face many issues So pls postpone #INDIAunitedtoPostponeJEE_NEET'],
#  ["There are now 4,293 active #COVID19 cases in VIC, with 182 new cases. I'm sad to say that 13 more people have died because of this virus. Wyndham - 458 active cases Hobsons Bay - 133 active cases Please stay home, wear a mask &amp; get tested. https://www.dhhs.vic.gov.au/coronavirus #springst"],
#  ['Covid update https://www.instagram.com/p/CELynUAnB2z/?igshid=1cj5khms3mhbn #news #updates #covid19 #nammabengaluru #karnataka #india #Bengaluru #covid'],
#  ['#IndiaFightsCorona: Parenting tips during #COVID19: Stay calm and firm Build mutual respect &amp; trust Be there for your child Seek professional support in need Call childline at #StaySafe #HealthForAll #indiawillwin @PMOIndia @AzamgarhFob @InfoDeptUP'],
#  ['Help slow the spread of #COVID19 and identify at risk cases sooner by self-reporting your symptoms daily, even if you feel well . Download the app '],
#  ['I’m thinking of going to a hotel for my birthday. I just need one with everything open for use. I need the complimentary breakfast, pool, exercise and computer room. #Covid19 #Sucks #GoAwayCoronaVirus'],
#  ['"2020 ou la crise du bon sens" par @bernardrentier https://bernardrentier.wordpress.com/2020/08/21/2020-ou-la-crise-du-bon-sens/ Avec la #bonsensite, nos amis français vont encore plus nous apprécier et moins nous comprendre... #COVID19 #Covid19be'],
#  ['Mayor ritmo de contagios de la UE, pero que no nos quiten las ganas de fiesta, que es agosto Anoche (bueno, y todas) 20 chavales debajo de mi casa haciendo botellón, pegando voces y sin mascarilla hasta las 5 de la mañana. ¿ESTAMOS GILIPOLLAS O QUÉ? #COVID19 #VueltaSegura'],
#  ['Hukukun ustunlugu degil ustunlerin hukuku gibi duzenli #coronavirus #covid19 testi yaptiranlar da pozitif cikinca anliypruz ki yeni lumpenlerimiz #akp baskani #erdogan &amp; avaneleri! Hizmetkar olmaya degil efendi olmaya gelmisler ki boyledir, buralar hep dutluktu, #turkiye cinneti.'],
#  ['#protocol #precautions #covid #conditions #corona #virus #coronavirus #covid19 #foreverwaiting #princesspeace #rebelliousprincess #badassprincess #Daddyslittleprincess #peoplesprincess #august #iluvlove #misnmahking #misnmahprinsuz #misnmaheroz #luvmahqueens'],
#  ['‘’People must have righteous principals in the first, and then they will not fail to perform virtuous actions.’’ #SaturdayThoughts #India #USA... #coronavirus #Covid_19 #COVIDー19 #COVID #COVID19 #Corona #COVID2019 #StayHomeStaySafe #principles #Karma #good #Righteous #Action #'],
#  ['8/22 17:07時点の新規感染者数 東京都 256人 愛知県 69人 千葉県 43人 兵庫県 33人 沖縄県 31人 神奈川県 25人 北海道 16人 熊本県 11人 奈良県 9人 宮崎県 8人 山口県 7人 長野県 6人 静 ... 詳細はこちら➔https://hmts.jp/corona #新型コロナウイルス #COVID19'],
#  [' Desde hoy estamos en déficit con la Tierra. Hoy es el #DíaDeLaSobrecapacidad #OvershootDay y ya hemos consumido todos los recursos que teníamos para un año. Este 2020 se ha retrasado algo por la #COVID19 pero aún así es terrible. No podemos seguir así '],
#  ['`எஸ்.பி.பி பங்கேற்ற நிகழ்ச்சியில் நானும் ஒருத்தி; வதந்தியை பரப்பாதீங்க’- பாடகி மாளவிகா விளக்கம்... #SPB #SingerMalavika #Covid19 #எஸ்பிபி #பாடகிமாளவிகா #கோவிட்19'],
#  ['Had a couple beers and completely tuned into a generator infomercial. Now this is good solid American livin’. #COVID19 #tropicalstorm #HurricaneSeason'],
#  ['#Kenya’s drinking culture is being redefined due to #COVID19 says East African Breweries Chief Financial Officer Risper Ohaga. Report by @whitehouse789'],
#  ["Hold a public inquiry into the Government's handling of the Covid-19 pandemic #Covid19 - Sign the Petition! http://chng.it/Hg7227Fx via @UKChange"],
#  ['Victoria Falls On Life Support As Covid-19 Continues to Bite @Zimindependent: https://allafrica.com/stories/202008220078.html?utm_campaign=allafrica%3Aeditor&amp;utm_medium=social&amp;utm_source=twitter&amp;utm_content=promote%3Aaans%3Aabkwtb #Zimbabwe #Coronavirus #Covid19 '],
#  ['8 Lakh Students for JEE Entrance and almost 15 lakhs Students for NEET entrance exams are going to write the Exams during this #covid19 times. Pray to God that Not even a Single Student and Their Parents/Whoever Accompanying them to Exams should not Get Affected of #COVID19India'],
#  ['Et suivant le temps avec parapluie ou Bonnet, écharpe #Blanquer #COVID19 sans oublier un mégaphone pour se faire entendre... '],
#  ['#IndiaFightsCorona another crucial milestone in the fight against #COVID19 India is testing more than 1,000,000 people/day Read more: https://bit.ly/2QbDUv4'],
#  ["Are we going to learn from other countries who are ahead of us once more, of course not. In you go kids we're all collateral. Could have just paid everyone a wage for a year until the vaccines get here but that would put too big a dent in the elites balance sheets. #COVID19 "],
#  ['#COVID19 expenditure will eventually show up in audit calendar of the OAG, the #SAI of Nepal but as previously suggested during my tenure, proactive application of four eyes principle during emergency procurement goes long way to ensure fiduciary risk is managed properly. #Nepal'],
#  ['#Video | दुनियाभर में #COVID19 पर असुरक्षित अवैज्ञानिक दावों के कारण कम से कम 800 लोगों की मौत '],
#  ['Hostelería local de #VitoriaGasteiz El Ayto está otorgando licencias provisionales a pub y discotecas para que puedan abrir como bares con cierre a la 1h. Mientras los hosteleros guardaron ayer un #MinutoDeSilencio en homenaje a Moha de @Sagartoki #Covid19 '],
#  ['4.1m people - more data than any other study. Help slow the spread of #COVID19 and identify at risk cases sooner by self-reporting your symptoms daily, even if you feel well . Download the app '],
#  ['#COVID19 only kills people already hospitalised for terminal illnesses Some cities were shit at keeping the elderly safe ~ all Labor run &amp; all Democrat run in the US especially the murderers in NYC who parked Covid cases in old people’s homes!'],
#  ['#ReadingNow: first issue of the #COVID19 Dispatch! Click the link to learn about a new intervention helping families and how you can join in the #WearAMask challenge https://mailchi.mp/45bf51b70eaa/covid19dispatch-issue1 Please #rt'],
#  ["Et là c'est pas la dictature ????? Légal cette méthode digne de la Coree du nord??? #DictatureSanitaire Interpellation d’un salarié à sont lieu de travail pour un masque sous le nez - Video internet #COVID19 #CORONAVIRUSFRANCE #MasqueObligatoire"],
#  ['If we tell you that wearing a mask will help YOU, will that make you feel better about wearing one? Rather than saying ‘others’ So many more people slacking the more the days go on. The pandemic is not over just because YOU’RE over it! #COVID19 #COVIDIOTS'],
#  ['New video @https://youtu.be/7Q5KPe-wUcc love and blessing for you. #music #YouTube #Makhadzi #COVID19 #musiccovers #Kimwalker #SaturdayMotivation #BBNaijialockdown2020 #protector #musiccover #YokiYoki #creatives'],
#  ['I hope my 6 numbers come up too!! #COVID19 '],
#  ['Congratulations @Sanchit30497977 and @drshalimar on this well written letter to the editor on #COVID19 and #Cirrhosis @Gut_BMJ continues to publish high quality articles and also the letters that add to those articles. Well done all!'],
#  ['#IndiaFightsCorona: How smoking makes people more vulnerable to #COVID19 It leads to lung diseases It reduces lung capacity Cigarettes may lead to virus transmission from hand to mouth #StaySafe #StayHome #IndiaWillWin Via MIB @PMOIndia @InfoDeptUP @BOC_MIB'],
#  ['https://www.newtral.es/nos-preguntais-por-los-centros-de-salud-cerrados-en-madrid/20200520/ Pero @IdiazAyuso sigue a lo suyo. #SanidadPública #Vallecas #Rastreadores #ServiciosPúblicos #Residencias . #COVID19 '],
#  ['The treasury’s filled with depression The country has entered recession The figures just out Leave no one in doubt We’re now facing months of regression #Quangleverse #COVID19 #coronavirus #recession #depression #money #Finances #economy #poetry'],
#  ['#COVID19 Hamish 65, Edinburgh, it’s all bollocks man! I’m not having it at all, I don’t believe the numbers! Something is going on! #newnormal2020 #coronavirus'],
#  ['KKM ambil tindakan kompaun pada 7 Ogos selepas Khairuddin gagal patuhi SOP kuarantin #BHnasional #COVID19 '],
#  ["#RT @phocuswire: LIVE BLOG: Beijing airport's touchless system goes from check-in to gate http://bit.ly/3amhdfP via @PhocusWire #coronavirus #coronavirusupdates #covid19 #corona #travel #tourism #china #Beijing"],
#  ["Don't Look Now But COVID-19 Cases Are Dropping - The Rush Limbaugh Show #CoronavirusOutbreak #covid19 "],
#  ['The latest COVID-19 Daily News! http://covid-19dailynews.com/?edition_id=569dddf0-e44e-11ea-a7d6-0cc47a0d164b Thanks to @lellingw @egslr123 @kieranperry_uk #covid19 #coronavirus'],
#  ['Today’s SBC Prayer #sbcprayer #dailyprayer #selsdon #bereavement #grief #lostlovedones #southcroydon #covid19 #grieving #sadness'],
#  ['Umakyat sa 187,249 ang kabuuang bilang ng kumpirmadong kaso ng #COVID19 sa Pilipinas base sa datos ng Department of Health ngayong araw, Agosto 22, 2020. Para sa pinakabagong balita tungkol sa COVID-19, bisitahin ang: http://news.abs-cbn.com/covid19-watch'],
#  ['Morning hope you listened to it . . . . . . . . #musicislife #lovelive #Upcomingartist #Rapper #rap #SaturdayMotivation #COVID19 #audiomack #KingsDisease'],
#  ['Rate his freestyle ....Pur-phy Don #BBNaijialockdown2020 #SEVINT #KingsDisease #DramaZaKenyansAbroad #DynamiteBTS #MaliFakeIende #COVID19 #iamnotokaywiththis #Dynamite100M #SmackDown #لبنانيين_يتعرون_في_الخبر #WWEThunderDome #BTS_Dynamite #INDIAun'],
#  ['Please be aware as certain areas are surging again. Stay Safe, wear a mask, and keep your distance! #Repost @who To stop the spread of #COVID19, we all need to play our part. Help protect those who need it most. #SGRhoCentral #CentralWearYourMask #CentralSocialDistance '],
#  ["@piersmorgan have you looked into all the road closures going on in London against the wishes of residents and businesses under the banner of #COVID19 would be great for the council's to be held accountable @SuttonCouncil Disgrase to democracy"],
#  ['Maduro postula a Venezuela para producir vacunas contra #Covid19 de Rusia o China https://bit.ly/3aJXOGO·'],
#  ['【新型コロナウイルス】阿波おどり中止で廃業を検討しています…… #新型コロナ #COVID19 #阿波踊り']]

# %%
for i in range(0, length):
    text=text_tweets[i][0]+ " "+ text
    
lower_case=text.lower()

cleaned_text=lower_case.translate(str.maketrans('', '', string.punctuation))

tokenized_words=cleaned_text.split()

# %%
cleaned_text
# Out:
# '【新型コロナウイルス】阿波おどり中止で廃業を検討しています…… 新型コロナ covid19 阿波踊り maduro postula a venezuela para producir vacunas contra covid19 de rusia o china httpsbitly3ajxogo· piersmorgan have you looked into all the road closures going on in london against the wishes of residents and businesses under the banner of covid19 would be great for the councils to be held accountable suttoncouncil disgrase to democracy please be aware as certain areas are surging again stay safe wear a mask and keep your distance repost who to stop the spread of covid19 we all need to play our part help protect those who need it most sgrhocentral centralwearyourmask centralsocialdistance  rate his freestyle purphy don bbnaijialockdown2020 sevint kingsdisease dramazakenyansabroad dynamitebts malifakeiende covid19 iamnotokaywiththis dynamite100m smackdown لبنانيينيتعرونفيالخبر wwethunderdome btsdynamite indiaun morning hope you listened to it         musicislife lovelive upcomingartist rapper rap saturdaymotivation covid19 audiomack kingsdisease umakyat sa 187249 ang kabuuang bilang ng kumpirmadong kaso ng covid19 sa pilipinas base sa datos ng department of health ngayong araw agosto 22 2020 para sa pinakabagong balita tungkol sa covid19 bisitahin ang httpnewsabscbncomcovid19watch today’s sbc prayer sbcprayer dailyprayer selsdon bereavement grief lostlovedones southcroydon covid19 grieving sadness the latest covid19 daily news httpcovid19dailynewscomeditionid569dddf0e44e11eaa7d60cc47a0d164b thanks to lellingw egslr123 kieranperryuk covid19 coronavirus dont look now but covid19 cases are dropping  the rush limbaugh show coronavirusoutbreak covid19  rt phocuswire live blog beijing airports touchless system goes from checkin to gate httpbitly3amhdfp via phocuswire coronavirus coronavirusupdates covid19 corona travel tourism china beijing kkm ambil tindakan kompaun pada 7 ogos selepas khairuddin gagal patuhi sop kuarantin bhnasional covid19  covid19 hamish 65 edinburgh it’s all bollocks man i’m not having it at all i don’t believe the numbers something is going on newnormal2020 coronavirus the treasury’s filled with depression the country has entered recession the figures just out leave no one in doubt we’re now facing months of regression quangleverse covid19 coronavirus recession depression money finances economy poetry httpswwwnewtralesnospreguntaisporloscentrosdesaludcerradosenmadrid20200520 pero idiazayuso sigue a lo suyo sanidadpública vallecas rastreadores serviciospúblicos residencias  covid19  indiafightscorona how smoking makes people more vulnerable to covid19 it leads to lung diseases it reduces lung capacity cigarettes may lead to virus transmission from hand to mouth staysafe stayhome indiawillwin via mib pmoindia infodeptup bocmib congratulations sanchit30497977 and drshalimar on this well written letter to the editor on covid19 and cirrhosis gutbmj continues to publish high quality articles and also the letters that add to those articles well done all i hope my 6 numbers come up too covid19  new video httpsyoutube7q5kpewucc love and blessing for you music youtube makhadzi covid19 musiccovers kimwalker saturdaymotivation bbnaijialockdown2020 protector musiccover yokiyoki creatives if we tell you that wearing a mask will help you will that make you feel better about wearing one rather than saying ‘others’ so many more people slacking the more the days go on the pandemic is not over just because you’re over it covid19 covidiots et là cest pas la dictature  légal cette méthode digne de la coree du nord dictaturesanitaire interpellation d’un salarié à sont lieu de travail pour un masque sous le nez  video internet covid19 coronavirusfrance masqueobligatoire readingnow first issue of the covid19 dispatch click the link to learn about a new intervention helping families and how you can join in the wearamask challenge httpsmailchimp45bf51b70eaacovid19dispatchissue1 please rt covid19 only kills people already hospitalised for terminal illnesses some cities were shit at kee ...

# %%
import nltk
from nltk.corpus import stopwords
set(stopwords.words('english'))
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself",
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these",
              "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do",
              "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while",
              "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before",
              "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again",
              "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each",
              "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
              "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]


final_words=[word for word in tokenized_words if word not in stop_words]

# %%
emotion_list=[]
with open('D:/New Folder (2)/emotions.txt','r') as file:
    for line in file:
        clear_line=line.replace('\n','').replace(',','').replace("'",'').strip()
        word, emotion=clear_line.split(':')
        if word in final_words:
            emotion_list.append(emotion)
            
w=Counter(emotion_list)
print(w)
# Out:
# Counter({' attracted': 1, ' safe': 1, ' fearless': 1, ' fearful': 1, ' sad': 1, ' powerless': 1, ' happy': 1})

# %%
fig, ax1=plt.subplots()
ax1.bar(w.keys(), w.values())
fig.autofmt_xdate()
plt.savefig('graph.png')
plt.show()

# %%
def get_tweetss():
    import GetOldTweets3 as got 
    tweetCriteria=got.manager.TweetCriteria().setQuerySearch('#covid19') \
        .setSince("2020-04-03") \
        .setSince("2020-05-03") \
        .setMaxTweets(100)
    tweets=got.manager.TweetManager.getTweets(tweetCriteria)
    text_tweets=[[tweet.text] for tweet in tweets]
    return text_tweets

# %%
text=""
text_tweetss=get_tweetss()

length=len(text_tweetss)

# %%
for i in range(0, length):
    text=text_tweetss[i][0] + " " + text
    
lower_case=text.lower()

cleaned_texts=lower_case.translate(str.maketrans('','', string.punctuation))

tokenized_wordss=cleaned_texts.split()

# %%
cleaned_texts
# Out:
# 'plandemic scamdemic covidhoax covid19  lo mismo te piensas que lo que dices tiene un mínimo de coherenciaigual en vez de acusar injustamente a quienes nos han informado de verdad  te apetece recapacitar las idioteces que acabas de decircovid19 corona update samstag das rki meldet 2034 neuinfektionen das ist die höchste zunahme seit 119 tagen im durchschnitt der letzten 7 tage gab es 1322 tägliche neuinfektionen covid19 pandemie covid19de bot  e qui sempre ilariacapua che sul corriere definisce chi minimizza pericoloso insomma anche la capua dice tutto e il contrario di tutto a giorni alterni covid19 coronavirus ricordate può andare anche peggio di così 2020 gremlins covid19 coronavirus quando si fanno i compiti in classe si distanziano i banchi di circa 1 metro per non far copiare non si può utilizzare questo metodo anche per far rispettare il distanziamento sociale nelle aule invece di spendere soldi per gli inutili banchi monoposto azzolina covid19 india has crossed the milestone of conducting 10 lakh covid19 tests in a single day in a tweet health ministry said during the last 24 hours more than 10 lakh people were tested  4884 new cases and 26 new deaths in the philippines 1020 gmt coronavirus coronavirusupdate covid19 coronaviruspandemic la telemedicina puede ser un pilar fundamental del sistema sanitario mundial para dar solución a la salud de los ciudadanos y más en un momento como el actual con pandemia por covid19 bigdata digitaltransformation ods sostenibilidad never fall for a get rich quick scheme learn how to build or create wealth for yourself for as low as 10k you can get started be financially free with simple steps click below httpswalink0etl8v covid19 covidwarriors a happy ganeshchathurthi ganeshachaturthi2020 ganesh ganeshutsav covid19 ganeshotsav2020 happy ganesh chaturthi from la classe translation services team fight against  covid19 happyganeshchaturthi covid19 stayhome 24by7 foreignlanguages translation translators foreign languages translationservices contact  mob 9958298424 tel  01143048424 i have attended so many webinars during the lockdown but didnt get a single certificate i am jealous of his big bag for more fun follow me on instagram faisalnama01 lockdown covid19 webinar2020 technology stayhome staysafe protégez votre entourage contre la covid19 encouragez lhygiène respiratoire et le respect de létiquette liée à la toux  petrol prices in 2013  kolkata7732 mumbai8248 chennai7743 faridabad7539 gurgaon7515 noida7587 ghaziabad7576 no covid19 no tradewar no governance only corruption તમને ૨૦૧૩ માં મજા આવતી તી તો અવે પણ આવતીજ અશે ને bardancer zindabad bas  نصائع للتعامل مع الشعور بالتوتر أو الغضب covid19 aishaassociation dont only be concerned about covid19 but also d works which are closed coaching centres are closed since march shall people come to your home to have food and money to bear expenseswill led to more suide cases a frustrated citizen of new india ravishndtv incindia the abandonment of covid19 protections in auto plants takes place as the trump administration and democratic governors across the united states are working together to force a deadly reopening of schools workersoftheworldunite workers to the grade 12 pupils who wish to to better their marks we present to you an opportunity for learning through the facebook live blendedacademia zimbabweanslivesmatter nochillgain makhadzi covid19  80k gave comdek  30laks will give jeeneet thats 37times comdek if these exams r done then we have to face2k deaths  2 lakh ve nd 3 lakh quarantines in 1st week  do the math u ll get there  is it worth it  postponejeeneetsept indiaunitedtopostponeneetjee covid19 dénonciations menaces insultes violences le covid19 et la gestion catastrophique du président macron laisse ressortir le pire de lhumain the homeminister of the country chiefministers amp ministers of states celebrities like our formerpresident amp srbachchan  have not been spared by covid19 is it safe to send our children to schools  covid19  ...

# %%
stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself",
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these",
              "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do",
              "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while",
              "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before",
              "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again",
              "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each",
              "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
              "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

final_wordss=[word for word in tokenized_wordss if word not in stop_words]

# %%
emotion_lists=[]
with open('D:/New Folder (2)/emotions.txt','r') as file:
    for line in file:
        clear_lines=line.replace('\n','').replace("'",'').replace(',','').strip()
        word, emotion= clear_lines.split(':')
        if word in final_wordss:
            emotion_list.append(emotion)
            
w=Counter(emotion_list)
print(w)
# Out:
# Counter({' sad': 5, ' happy': 4, ' attracted': 3, ' powerless': 3, ' safe': 1, ' fearless': 1, ' fearful': 1, ' hated': 1, ' adequate': 1, ' surprise': 1, ' esteemed': 1, ' free': 1, ' angry': 1, ' entitled': 1})

# %%
fig, ax1=plt.subplots()
ax1.bar(w.keys(),w.values())
fig.autofmt_xdate()
plt.savefig('graph1.png')
plt.show()

# %% [markdown]
# # Part two

# %%
import string
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

import nltk
import warnings
warnings.filterwarnings('ignore')

# %%
text=open('D:/New Folder/Graduation_day.txt', encoding='utf-8').read()

lower_case=text.lower()

cleaned_text=lower_case.translate(str.maketrans('','',string.punctuation))

tokenized_words=word_tokenize(cleaned_text,"english")

# %%
final_words=[]

for word in tokenized_words:
    if word not in stopwords.words('english'):
        final_words.append(word)

# %%
final_words
# Out:
# ['\ufeffi',
#  'honored',
#  'today',
#  'commencement',
#  'one',
#  'finest',
#  'universities',
#  'world',
#  'never',
#  'graduated',
#  'college',
#  'truth',
#  'told',
#  'closest',
#  '’',
#  'ever',
#  'gotten',
#  'college',
#  'graduation',
#  'today',
#  'want',
#  'tell',
#  'three',
#  'stories',
#  'life',
#  '’',
#  'big',
#  'deal',
#  'three',
#  'stories',
#  'related',
#  'story',
#  '2005',
#  'stanford',
#  'commencement',
#  'coverage',
#  'first',
#  'story',
#  'connecting',
#  'dots',
#  'dropped',
#  'reed',
#  'college',
#  'first',
#  '6',
#  'months',
#  'stayed',
#  'around',
#  'dropin',
#  'another',
#  '18',
#  'months',
#  'really',
#  'quit',
#  'drop',
#  'started',
#  'born',
#  'biological',
#  'mother',
#  'young',
#  'unwed',
#  'college',
#  'graduate',
#  'student',
#  'decided',
#  'put',
#  'adoption',
#  'felt',
#  'strongly',
#  'adopted',
#  'college',
#  'graduates',
#  'everything',
#  'set',
#  'adopted',
#  'birth',
#  'lawyer',
#  'wife',
#  'except',
#  'popped',
#  'decided',
#  'last',
#  'minute',
#  'really',
#  'wanted',
#  'girl',
#  'parents',
#  'waiting',
#  'list',
#  'got',
#  'call',
#  'middle',
#  'night',
#  'asking',
#  '“',
#  'unexpected',
#  'baby',
#  'boy',
#  'want',
#  '”',
#  'said',
#  '“',
#  'course',
#  '”',
#  'biological',
#  'mother',
#  'later',
#  'found',
#  'mother',
#  'never',
#  'graduated',
#  'college',
#  'father',
#  'never',
#  'graduated',
#  'high',
#  'school',
#  'refused',
#  'sign',
#  'final',
#  'adoption',
#  'papers',
#  'relented',
#  'months',
#  'later',
#  'parents',
#  'promised',
#  'would',
#  'someday',
#  'go',
#  'college',
#  '17',
#  'years',
#  'later',
#  'go',
#  'college',
#  'naively',
#  'chose',
#  'college',
#  'almost',
#  'expensive',
#  'stanford',
#  'workingclass',
#  'parents',
#  '’',
#  'savings',
#  'spent',
#  'college',
#  'tuition',
#  'six',
#  'months',
#  '’',
#  'see',
#  'value',
#  'idea',
#  'wanted',
#  'life',
#  'idea',
#  'college',
#  'going',
#  'help',
#  'figure',
#  'spending',
#  'money',
#  'parents',
#  'saved',
#  'entire',
#  'life',
#  'decided',
#  'drop',
#  'trust',
#  'would',
#  'work',
#  'ok',
#  'pretty',
#  'scary',
#  'time',
#  'looking',
#  'back',
#  'one',
#  'best',
#  'decisions',
#  'ever',
#  'made',
#  'minute',
#  'dropped',
#  'could',
#  'stop',
#  'taking',
#  'required',
#  'classes',
#  '’',
#  'interest',
#  'begin',
#  'dropping',
#  'ones',
#  'looked',
#  'interesting',
#  '’',
#  'romantic',
#  '’',
#  'dorm',
#  'room',
#  'slept',
#  'floor',
#  'friends',
#  '’',
#  'rooms',
#  'returned',
#  'coke',
#  'bottles',
#  '5¢',
#  'deposits',
#  'buy',
#  'food',
#  'would',
#  'walk',
#  '7',
#  'miles',
#  'across',
#  'town',
#  'every',
#  'sunday',
#  'night',
#  'get',
#  'one',
#  'good',
#  'meal',
#  'week',
#  'hare',
#  'krishna',
#  'temple',
#  'loved',
#  'much',
#  'stumbled',
#  'following',
#  'curiosity',
#  'intuition',
#  'turned',
#  'priceless',
#  'later',
#  'let',
#  'give',
#  'one',
#  'example',
#  'reed',
#  'college',
#  'time',
#  'offered',
#  'perhaps',
#  'best',
#  'calligraphy',
#  'instruction',
#  'country',
#  'throughout',
#  'campus',
#  'every',
#  'poster',
#  'every',
#  'label',
#  'every',
#  'drawer',
#  'beautifully',
#  'hand',
#  'calligraphed',
#  'dropped',
#  '’',
#  'take',
#  'normal',
#  'classes',
#  'decided',
#  'take',
#  'calligraphy',
#  'class',
#  'learn',
#  'learned',
#  'serif',
#  'sans',
#  'serif',
#  'typefaces',
#  'varying',
#  'amount',
#  'space',
#  'different',
#  'letter',
#  'combinations',
#  'makes',
#  'great',
#  'typography',
#  'great',
#  'beautiful',
#  'historical',
#  'artistically',
#  'subtle',
#  'way',
#  'science',
#  '’',
#  'capture',
#  'found',
#  'fascinating',
#  'none',
#  'even',
#  'hope',
#  'practical',
#  'application',
#  'life',
#  '10',
#  'years',
#  'later',
#  'designing',
#  'first',
#  'macintosh',
#  'computer',
#  'came',
#  'back',
#  'designed',
#  'mac',
#  'first',
#  'computer',
#  'beautiful',
#  'typography',
#  'never',
#  'dropped',
#  'single',
#  'course',
#  'college',
#  'mac',
#  'would',
#  'never',
#  'multiple',
#  'typefaces',
#  'proportionally',
#  'spaced',
#  'fonts',
#  'since',
#  'windows',
#  'copied',
#  'mac',
#  '’',
#  'likely',
#  'personal',
#  'computer',
#  'would',
#  'never',
#  'dropped',
#  'would',
#  'never',
#  'dropped',
#  'calligraphy',
#  'class',
#  'personal',
#  'computers',
#  'might',
#  'wonderful',
#  'typography',
#  'course',
#  'impossible',
#  'connect',
#  'dots',
#  'looking',
#  'forward',
#  'college',
#  'clear',
#  'looking',
#  'backward',
#  '10',
#  'years',
#  'later',
#  '’',
#  'connect',
#  'dots',
#  'looking',
#  'forward',
#  'connect',
#  'looking',
#  'backward',
#  'trust',
#  'dots',
#  'somehow',
#  'connect',
#  'future',
#  'trust',
#  'something',
#  '—',
#  'gut',
#  'destiny',
#  'life',
#  'karma',
#  'whatever',
#  'approach',
#  'never',
#  'let',
#  'made',
#  'difference',
#  'life',
#  'second',
#  'story',
#  'love',
#  'loss',
#  'lucky',
#  '—',
#  'found',
#  'loved',
#  'early',
#  'life',
#  'woz',
#  'started',
#  'apple',
#  'parents',
#  '’',
#  'garage',
#  '20',
#  'worked',
#  'hard',
#  '10',
#  'years',
#  'apple',
#  'grown',
#  'two',
#  'us',
#  'garage',
#  '2',
#  'billion',
#  'company',
#  '4000',
#  'employees',
#  'released',
#  'finest',
#  'creation',
#  '—',
#  'macintosh',
#  '—',
#  'year',
#  'earlier',
#  'turned',
#  '30',
#  'got',
#  'fired',
#  'get',
#  'fired',
#  'company',
#  'started',
#  'well',
#  'apple',
#  'grew',
#  'hired',
#  'someone',
#  'thought',
#  'talented',
#  'run',
#  'company',
#  'first',
#  'year',
#  'things',
#  'went',
#  'well',
#  'visions',
#  'future',
#  'began',
#  'diverge',
#  'eventually',
#  'falling',
#  'board',
#  'directors',
#  'sided',
#  '30',
#  'publicly',
#  'focus',
#  'entire',
#  'adult',
#  'life',
#  'gone',
#  'devastating',
#  'really',
#  '’',
#  'know',
#  'months',
#  'felt',
#  'let',
#  'previous',
#  'generation',
#  'entrepreneurs',
#  '—',
#  'dropped',
#  'baton',
#  'passed',
#  'met',
#  'david',
#  'packard',
#  'bob',
#  'noyce',
#  'tried',
#  'apologize',
#  'screwing',
#  'badly',
#  'public',
#  'failure',
#  'even',
#  'thought',
#  'running',
#  'away',
#  'valley',
#  'something',
#  'slowly',
#  'began',
#  'dawn',
#  '—',
#  'still',
#  'loved',
#  'turn',
#  'events',
#  'apple',
#  'changed',
#  'one',
#  'bit',
#  'rejected',
#  'still',
#  'love',
#  'decided',
#  'start',
#  '’',
#  'see',
#  'turned',
#  'getting',
#  'fired',
#  'apple',
#  'best',
#  'thing',
#  'could',
#  'ever',
#  'happened',
#  'heaviness',
#  'successful',
#  'replaced',
#  'lightness',
#  'beginner',
#  'less',
#  'sure',
#  'everything',
#  'freed',
#  'enter',
#  'one',
#  'creative',
#  'periods',
#  'life',
#  'next',
#  'five',
#  'years',
#  'started',
#  'company',
#  'named',
#  'next',
#  'another',
#  'company',
#  'named',
#  'pixar',
#  'fell',
#  'love',
#  'amazing',
#  'woman',
#  'would',
#  'become',
#  'wife',
#  'pixar',
#  'went',
#  'create',
#  'world',
#  '’',
#  'first',
#  'computer',
#  'animated',
#  'feature',
#  'film',
#  'toy',
#  'story',
#  'successful',
#  'animation',
#  'studio',
#  'world',
#  'remarkable',
#  'turn',
#  'events',
#  'apple',
#  'bought',
#  'next',
#  'returned',
#  'apple',
#  'technology',
#  'developed',
#  'next',
#  'heart',
#  'apple',
#  '’',
#  'current',
#  'renaissance',
#  'laurene',
#  'wonderful',
#  'family',
#  'together',
#  '’',
#  'pretty',
#  'sure',
#  'none',
#  'would',
#  'happened',
#  '’',
#  'fired',
#  'apple',
#  'awful',
#  'tasting',
#  'medicine',
#  'guess',
#  'patient',
#  'needed',
#  'sometimes',
#  'life',
#  'hits',
#  'head',
#  'brick',
#  '’',
#  'lose',
#  'faith',
#  '’',
#  'convinced',
#  'thing',
#  'kept',
#  'going',
#  'loved',
#  '’',
#  'got',
#  'find',
#  'love',
#  'true',
#  'work',
#  'lovers',
#  'work',
#  'going',
#  'fill',
#  'large',
#  'part',
#  'life',
#  'way',
#  'truly',
#  'satisfied',
#  'believe',
#  'great',
#  'work',
#  'way',
#  'great',
#  'work',
#  'love',
#  '’',
#  'found',
#  'yet',
#  'keep',
#  'looking',
#  '’',
#  'settle',
#  'matters',
#  'heart',
#  '’',
#  'know',
#  'find',
#  'like',
#  'great',
#  'relationship',
#  'gets',
#  'better',
#  'better',
#  'years',
#  'roll',
#  'keep',
#  'looking',
#  'find',
#  '’',
#  'settle',
#  'third',
#  'story',
#  'death',
#  '17',
#  'read',
#  'quote',
#  'went',
#  'something',
#  'like',
#  '“',
#  'live',
#  'day',
#  'last',
#  'someday',
#  '’',
#  'certainly',
#  'right',
#  '”',
#  'made',
#  'impression',
#  'since',
#  'past',
#  '33',
#  'years',
#  'looked',
#  'mirror',
#  'every',
#  'morning',
#  'asked',
#  '“',
#  'today',
#  'last',
#  'day',
#  'life',
#  'would',
#  'want',
#  'today',
#  '”',
#  'whenever',
#  'answer',
#  '“',
#  '”',
#  'many',
#  'days',
#  'row',
#  'know',
#  'need',
#  'change',
#  'something',
#  'remembering',
#  '’',
#  'dead',
#  'soon',
#  'important',
#  'tool',
#  '’',
#  'ever',
#  'encountered',
#  'help',
#  'make',
#  'big',
#  'choices',
#  'life',
#  'almost',
#  'everything',
#  '—',
#  'external',
#  'expectations',
#  'pride',
#  'fear',
#  'embarrassment',
#  'failure',
#  '—',
#  'things',
#  'fall',
#  'away',
#  'face',
#  'death',
#  'leaving',
#  'truly',
#  'important',
#  'remembering',
#  'going',
#  'die',
#  'best',
#  'way',
#  'know',
#  'avoid',
#  'trap',
#  'thinking',
#  'something',
#  'lose',
#  'already',
#  'naked',
#  'reason',
#  'follow',
#  'heart',
#  'year',
#  'ago',
#  'diagnosed',
#  'cancer',
#  'scan',
#  '730',
#  'morning',
#  'clearly',
#  'showed',
#  'tumor',
#  'pancreas',
#  '’',
#  'even',
#  'know',
#  'pancreas',
#  'doctors',
#  'told',
#  'almost',
#  'certainly',
#  'type',
#  'cancer',
#  'incurable',
#  'expect',
#  'live',
#  'longer',
#  'three',
#  'six',
#  'months',
#  'doctor',
#  'advised',
#  'go',
#  'home',
#  'get',
#  'affairs',
#  'order',
#  'doctor',
#  '’',
#  'code',
#  'prepare',
#  'die',
#  'means',
#  'try',
#  'tell',
#  'kids',
#  'everything',
#  'thought',
#  '’',
#  'next',
#  '10',
#  'years',
#  'tell',
#  'months',
#  'means',
#  'make',
#  'sure',
#  'everything',
#  'buttoned',
#  'easy',
#  'possible',
#  'family',
#  'means',
#  'say',
#  'goodbyes',
#  'lived',
#  'diagnosis',
#  'day',
#  'later',
#  'evening',
#  'biopsy',
#  'stuck',
#  'endoscope',
#  'throat',
#  'stomach',
#  'intestines',
#  'put',
#  'needle',
#  'pancreas',
#  'got',
#  'cells',
#  'tumor',
#  'sedated',
#  'wife',
#  'told',
#  'viewed',
#  'cells',
#  'microscope',
#  'doctors',
#  'started',
#  'crying',
#  'turned',
#  'rare',
#  'form',
#  'pancreatic',
#  'cancer',
#  'curable',
#  'surgery',
#  'surgery',
#  '’',
#  'fine',
#  'closest',
#  '’',
#  'facing',
#  'death',
#  'hope',
#  '’',
#  'closest',
#  'get',
#  'decades',
#  'lived',
#  'say',
#  'bit',
#  'certainty',
#  'death',
#  'useful',
#  'purely',
#  'intellectual',
#  'concept',
#  'one',
#  'wants',
#  'die',
#  'even',
#  'people',
#  'want',
#  'go',
#  'heaven',
#  '’',
#  'want',
#  'die',
#  'get',
#  'yet',
#  'death',
#  'destination',
#  'share',
#  'one',
#  'ever',
#  'escaped',
#  'death',
#  'likely',
#  'single',
#  'best',
#  'invention',
#  'life',
#  'life',
#  '’',
#  'change',
#  'agent',
#  'clears',
#  'old',
#  'make',
#  'way',
#  'new',
#  'right',
#  'new',
#  'someday',
#  'long',
#  'gradually',
#  'become',
#  'old',
#  'cleared',
#  'away',
#  'sorry',
#  'dramatic',
#  'quite',
#  'true',
#  'time',
#  'limited',
#  '’',
#  'waste',
#  'living',
#  'someone',
#  'else',
#  '’',
#  'life',
#  '’',
#  'trapped',
#  'dogma',
#  '—',
#  'living',
#  'results',
#  'people',
#  '’',
#  'thinking',
#  '’',
#  'let',
#  'noise',
#  'others',
#  '’',
#  'opinions',
#  'drown',
#  'inner',
#  'voice',
#  'important',
#  'courage',
#  'follow',
#  'heart',
#  'intuition',
#  'somehow',
#  'already',
#  'know',
#  'truly',
#  'want',
#  'become',
#  'everything',
#  'else',
#  'secondary',
#  'young',
#  'amazing',
#  'publication',
#  'called',
#  'whole',
#  'earth',
#  'catalog',
#  'one',
#  'bibles',
#  'generation',
#  'created',
#  'fellow',
#  'named',
#  'stewart',
#  'brand',
#  'far',
#  'menlo',
#  'park',
#  'brought',
#  'life',
#  'poetic',
#  'touch',
#  ...]

# %%
lemma_words=[]

for word in final_words:
    word=WordNetLemmatizer().lemmatize(word)
    lemma_words.append(word)

# %%
emotion_list=[]
with open('D:/New Folder (2)/emotions.txt','r') as file:
    for line in file:
        clear_line=line.replace('\n','').replace("'",'').strip()
        word, emotion=clear_line.split(':')
        
        if word in lemma_words:
            emotion_list.append(emotion)
            
print('people emotions', emotion_list,'\n\n')

w=Counter(emotion_list)
print('count of each emotion \n',w)
# Out:
# people emotions [' happy,', ' happy,', ' attached,', ' happy,', ' attracted,', ' alone,', ' free,', ' hated,', ' happy,', ' entitled,', ' happy,', ' loved,', ' hated,', ' entitled,']
#
#
# count of each emotion
#  Counter({' happy,': 5, ' hated,': 2, ' entitled,': 2, ' attached,': 1, ' attracted,': 1, ' alone,': 1, ' free,': 1, ' loved,': 1})

# %% [markdown]
# # Part_3

# %%
from sklearn.feature_extraction.text import CountVectorizer

from nltk.corpus import stopwords
import pandas as pd

BOW_A=open('D:/New Folder/BOW_DOC_A.txt', encoding='utf-8').read()

vect1=CountVectorizer()

vect1.fit_transform(BOW_A)

vect1.get_feature_names()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-102-5f05b47e0c6e> in <module>
#       4 import pandas as pd
#       5
# ----> 6 BOW_A=open('D:/New Folder/BOW_DOC_A.txt', encoding='utf-8').read()
#       7
#       8 vect1=CountVectorizer()
#
# C:\ProgramData\Anaconda3\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 173: invalid start byte
