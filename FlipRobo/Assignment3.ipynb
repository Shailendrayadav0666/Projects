# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Conv2D,MaxPooling2D,Activation,Flatten,ZeroPadding2D
from keras.models import Sequential
from keras import optimizers

# %%
train="D:/Training/"

# %%
from os import listdir
from os.path import isfile, join
import numpy
import cv2
mypath='D:/Training/'
onlyfiles = [ f for f in listdir(mypath) if isfile(join(mypath,f)) ]
images = numpy.empty(len(onlyfiles), dtype=object)
for n in range(0, len(onlyfiles)):
  images[n] = cv2.imread( join(mypath,onlyfiles[n]) )

# %%
print(onlyfiles)
# Out:
# ['img_01 (2).jpeg', 'img_01.jpeg', 'img_02 (2).jpeg', 'img_02.jpeg', 'img_03 (2).jpeg', 'img_03.jpeg', 'img_101 (2).jpeg', 'img_101.jpeg', 'img_102 (2).jpeg', 'img_102.jpeg', 'img_103 (2).jpeg', 'img_103.jpeg', 'img_11 (2).jpeg', 'img_11.jpeg', 'img_111 (2).jpeg', 'img_111.jpeg', 'img_112 (2).jpeg', 'img_112.jpeg', 'img_113 (2).jpeg', 'img_113.jpeg', 'img_12 (2).jpeg', 'img_12.jpeg', 'img_121 (2).jpeg', 'img_121.jpeg', 'img_122 (2).jpeg', 'img_122.jpeg', 'img_123 (2).jpeg', 'img_123.jpeg', 'img_13 (2).jpeg', 'img_13.jpeg', 'img_131 (2).jpeg', 'img_131.jpeg', 'img_132 (2).jpeg', 'img_132.jpeg', 'img_133 (2).jpeg', 'img_133.jpeg', 'img_141 (2).jpeg', 'img_141.jpeg', 'img_142 (2).jpeg', 'img_142.jpeg', 'img_143 (2).jpeg', 'img_143.jpeg', 'img_151 (2).jpeg', 'img_151.jpeg', 'img_152 (2).jpeg', 'img_152.jpeg', 'img_153 (2).jpeg', 'img_153.jpeg', 'img_161 (2).jpeg', 'img_161.jpeg', 'img_162 (2).jpeg', 'img_162.jpeg', 'img_163 (2).jpeg', 'img_163.jpeg', 'img_171 (2).jpeg', 'img_171.jpeg', 'img_172 (2).jpeg', 'img_172.jpeg', 'img_173 (2).jpeg', 'img_173.jpeg', 'img_181 (2).jpeg', 'img_181.jpeg', 'img_182 (2).jpeg', 'img_182.jpeg', 'img_183 (2).jpeg', 'img_183.jpeg', 'img_191 (2).jpeg', 'img_191.jpeg', 'img_192 (2).jpeg', 'img_192.jpeg', 'img_193 (2).jpeg', 'img_193.jpeg', 'img_201 (2).jpeg', 'img_201.jpeg', 'img_202 (2).jpeg', 'img_202.jpeg', 'img_203 (2).jpeg', 'img_203.jpeg', 'img_21 (2).jpeg', 'img_21.jpeg', 'img_211 (2).jpeg', 'img_211.jpeg', 'img_212 (2).jpeg', 'img_212.jpeg', 'img_213 (2).jpeg', 'img_213.jpeg', 'img_22 (2).jpeg', 'img_22.jpeg', 'img_221 (2).jpeg', 'img_221.jpeg', 'img_222 (2).jpeg', 'img_222.jpeg', 'img_223 (2).jpeg', 'img_223.jpeg', 'img_23 (2).jpeg', 'img_23.jpeg', 'img_231 (2).jpeg', 'img_231.jpeg', 'img_31 (2).jpeg', 'img_31.jpeg', 'img_32 (2).jpeg', 'img_32.jpeg', 'img_33 (2).jpeg', 'img_33.jpeg', 'img_41 (2).jpeg', 'img_41.jpeg', 'img_42 (2).jpeg', 'img_42.jpeg', 'img_43 (2).jpeg', 'img_43.jpeg', 'img_51 (2).jpeg', 'img_51.jpeg', 'img_52 (2).jpeg', 'img_52.jpeg', 'img_53 (2).jpeg', 'img_53.jpeg', 'img_61 (2).jpeg', 'img_61.jpeg', 'img_62 (2).jpeg', 'img_62.jpeg', 'img_63 (2).jpeg', 'img_63.jpeg', 'img_71 (2).jpeg', 'img_71.jpeg', 'img_72 (2).jpeg', 'img_72.jpeg', 'img_73 (2).jpeg', 'img_73.jpeg', 'img_81 (2).jpeg', 'img_81.jpeg', 'img_82 (2).jpeg', 'img_82.jpeg', 'img_83 (2).jpeg', 'img_83.jpeg', 'img_91 (2).jpeg', 'img_91.jpeg', 'img_92 (2).jpeg', 'img_92.jpeg', 'img_93 (2).jpeg', 'img_93.jpeg']

# %%
for i in onlyfiles:
    image=cv2.imread("D:/Training/"+i)
    height,width=image.shape[:2]
    rotation_matrix=cv2.getRotationMatrix2D((width/2,height/2),30,.5)
    rotated_image=cv2.warpAffine(image, rotation_matrix,(width,height))
    cv2.imshow('rotated image',rotated_image)
    cv2.waitKey()
    cv2.destroyAllWindows()
    cv2.imwrite('augmented.jpg',input)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-8f1d5c935c9a> in <module>
#       7     cv2.waitKey()
#       8     cv2.destroyAllWindows()
# ----> 9     cv2.imwrite('augmented.jpg',input)
#
# TypeError: img is not a numpy array, neither a scalar
