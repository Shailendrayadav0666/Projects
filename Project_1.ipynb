# %%
# !pip install sqlalchemy

# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# %%
engine=create_engine('mysql+mysqlconnector://root:'+'Victory@2018'+'@localhost/student_marks')

# %%
df=pd.read_sql_table('studmarks',engine)
df
# Out:
#        Name Gender       DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M   5041988     55       45         56       87       21
# 1    Suresh      M   4051987     75       96         78       64       90
# 2    Ramesh      M  25051989     25       54         89       76       95
# 3   Jessica      F  12081990     78       96         86       63       54
# 4  Jennifer      F   2091989     58       96         78       46       96
# 5      Annu      F   5041988     45       87         52       89       55
# 6     pooja      F   4051987     55       64         61       58       75
# 7    Ritesh      M  25051989     54       76         87       56       25
# 8     Farha      F  12081990     55       63         89       75       78
# 9    Mukesh      M   2091989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
df.isnull()
# Out:
#     Name  Gender    DOB  Maths  Physics  Chemistry  English  Biology  \
# 0  False   False  False  False    False      False    False    False
# 1  False   False  False  False    False      False    False    False
# 2  False   False  False  False    False      False    False    False
# 3  False   False  False  False    False      False    False    False
# 4  False   False  False  False    False      False    False    False
# 5  False   False  False  False    False      False    False    False
# 6  False   False  False  False    False      False    False    False
# 7  False   False  False  False    False      False    False    False
# 8  False   False  False  False    False      False    False    False
# 9  False   False  False  False    False      False    False    False
#
#    Economics  History  Civics
# 0      False    False   False
# 1      False    False   False
# 2      False    False   False
# 3      False    False   False
# 4      False    False   False
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Gender       0
# DOB          0
# Maths        0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civics       0
# dtype: int64

# %%
df.dtypes
# Out:
# Name         object
# Gender       object
# DOB           int64
# Maths         int64
# Physics       int64
# Chemistry     int64
# English       int64
# Biology       int64
# Economics     int64
# History       int64
# Civics        int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.isnull())
plt.show()

# %%
dfcor=df.corr()
dfcor
# Out:
#                 DOB     Maths   Physics  Chemistry   English   Biology  \
# DOB        1.000000 -0.529127 -0.120460   0.608152 -0.095521 -0.129025
# Maths     -0.529127  1.000000  0.113354   0.076751 -0.064074 -0.146598
# Physics   -0.120460  0.113354  1.000000   0.117192 -0.562608  0.279638
# Chemistry  0.608152  0.076751  0.117192   1.000000 -0.409680  0.318032
# English   -0.095521 -0.064074 -0.562608  -0.409680  1.000000 -0.330844
# Biology   -0.129025 -0.146598  0.279638   0.318032 -0.330844  1.000000
# Economics  0.056600  0.000312  0.191851   0.235390  0.237577  0.370531
# History   -0.095521 -0.320846  0.334082  -0.482710 -0.038775 -0.456131
# Civics     0.456901 -0.274629 -0.643266   0.210908  0.186705 -0.330060
#
#            Economics   History    Civics
# DOB         0.056600 -0.095521  0.456901
# Maths       0.000312 -0.320846 -0.274629
# Physics     0.191851  0.334082 -0.643266
# Chemistry   0.235390 -0.482710  0.210908
# English     0.237577 -0.038775  0.186705
# ...

# %%
sns.heatmap(dfcor,annot=True)
plt.show()

# %%
df.skew()
#cannot delete the data which is above .50 as they are marks scored by students.
# Out:
# DOB          1.179591
# Maths        0.246964
# Physics     -0.045336
# Chemistry   -0.746462
# English     -0.131222
# Biology     -0.496446
# Economics   -0.245555
# History     -0.131222
# Civics      -1.332448
# dtype: float64

# %%
df.describe()
# Out:
#                 DOB      Maths    Physics  Chemistry    English    Biology  \
# count  1.000000e+01  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   9.663989e+06  59.600000  72.300000  75.300000  69.700000  64.700000
# std    8.854753e+06  19.460501  20.661559  14.000397  14.453373  26.998148
# min    2.091989e+06  25.000000  45.000000  52.000000  46.000000  21.000000
# 25%    4.051987e+06  54.250000  56.250000  65.000000  59.250000  54.250000
# 50%    5.041988e+06  55.000000  70.000000  78.000000  69.500000  66.500000
# 75%    1.208199e+07  70.750000  93.750000  86.750000  81.250000  87.000000
# max    2.505199e+07  96.000000  96.000000  89.000000  89.000000  96.000000
#
#        Economics    History   Civics
# count  10.000000  10.000000  10.0000
# mean   72.700000  69.700000  60.5000
# std    14.629119  14.453373  25.3432
# min    52.000000  46.000000   2.0000
# 25%    58.750000  59.250000  52.2500
# 50%    76.000000  69.500000  63.0000
# ...

# %%
df['Biology'].plot.box()

# %%
sns.pairplot(df)
